# %% [markdown]
# SENSORIMOTOR GROUNDING

# %% [raw]
# Bar chart on polar axis for Sensorimotor grounding in animal sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 7
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [7.8,0.81,0.53,0,0,0.7,12.2]
width = 4 / 4 * np.random.rand(N)
colors = ['lightgreen', 'aquamarine', 'coral', 'lightpink', 'mediumpurple', 'gold', 'mediumseagreen']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,8)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["VISION", "TOUCH", "HEARING", "SMELL", "TASTE", "MATERIAL", "NP_EV"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_animals.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Sensorimotor grounding in food sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 7
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [5.9,0.1,0,0.1,9.8,6.3,4.1]
width = 4 / 4 * np.random.rand(N)
colors = ['lightgreen', 'aquamarine', 'coral', 'lightpink', 'mediumpurple', 'gold', 'mediumseagreen']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,8)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["VISION", "TOUCH", "HEARING", "SMELL", "TASTE", "MATERIAL", "NP_EV"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_food.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Sensorimotor grounding in tool sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 7
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [7.1,0.72,0.61,0,0.1,3.5,5.6]
width = 4 / 4 * np.random.rand(N)
colors = ['lightgreen', 'aquamarine', 'coral', 'lightpink', 'mediumpurple', 'gold', 'mediumseagreen']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,8)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["VISION", "TOUCH", "HEARING", "SMELL", "TASTE", "MATERIAL", "NP_EV"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_tool.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Sensorimotor grounding in PS sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 7
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.5,0,0,0,0,0,6.7]
width = 4 / 4 * np.random.rand(N)
colors = ['lightgreen', 'aquamarine', 'coral', 'lightpink', 'mediumpurple', 'gold', 'mediumseagreen']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,8)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["VISION", "TOUCH", "HEARING", "SMELL", "TASTE", "MATERIAL", "NP_EV"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_PS.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Sensorimotor grounding in PSQT sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 7
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [1.1,0.1,0,0,0,0,8.2]
width = 4 / 4 * np.random.rand(N)
colors = ['lightgreen', 'aquamarine', 'coral', 'lightpink', 'mediumpurple', 'gold', 'mediumseagreen']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,8)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["VISION", "TOUCH", "HEARING", "SMELL", "TASTE", "MATERIAL", "NP_EV"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_PSQT.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Sensorimotor grounding in EMSS sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 7
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.5,0,0.1,0,0,0,12.5]
width = 4 / 4 * np.random.rand(N)
colors = ['lightgreen', 'aquamarine', 'coral', 'lightpink', 'mediumpurple', 'gold', 'mediumseagreen']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,8)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["VISION", "TOUCH", "HEARING", "SMELL", "TASTE", "MATERIAL", "NP_EV"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_EMSS.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# CONVERSATION

# %% [raw]
# Bar chart on polar axis for Conversation in animal sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 10
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.7,6.2,0.6,3.5,5,20.4,9.9,1,1,3.3]
width = 4 / 4 * np.random.rand(N)
colors = ['darkorange', 'pink', 'dodgerblue', 'magenta', 'darkturquoise', 'mediumorchid', 'lightsalmon', 'lawngreen', 'deepskyblue', 'red']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,11)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["U_EXPR", "T_W_REP", "N°_QUEST", "WHY", "HOW", "WHERE", "WHAT", "WHEN", "WHO", "GS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_conv_animals.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Conversation in food sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 10
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0,5.4,0.5,1,17.8,3,4.3,1.4,0.6,1.7]
width = 4 / 4 * np.random.rand(N)
colors = ['darkorange', 'pink', 'dodgerblue', 'magenta', 'darkturquoise', 'mediumorchid', 'lightsalmon', 'lawngreen', 'deepskyblue', 'red']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,11)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["U_EXPR", "T_W_REP", "N°_QUEST", "WHY", "HOW", "WHERE", "WHAT", "WHEN", "WHO", "GS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_conv_food.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Conversation in tool sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 10
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.3,1,0.4,11,2.8,4.5,6.3,0.5,0.9,2.3]
width = 4 / 4 * np.random.rand(N)
colors = ['darkorange', 'pink', 'dodgerblue', 'magenta', 'darkturquoise', 'mediumorchid', 'lightsalmon', 'lawngreen', 'deepskyblue', 'red']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,11)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["U_EXPR", "T_W_REP", "N°_QUEST", "WHY", "HOW", "WHERE", "WHAT", "WHEN", "WHO", "GS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_conv_tool.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Conversation in PS sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 10
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [1.8,5.1,0.6,1.9,11.2,0.2,21.6,0.2,3,10.6]
width = 4 / 4 * np.random.rand(N)
colors = ['darkorange', 'pink', 'dodgerblue', 'magenta', 'darkturquoise', 'mediumorchid', 'lightsalmon', 'lawngreen', 'deepskyblue', 'red']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,11)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["U_EXPR", "T_W_REP", "N°_QUEST", "WHY", "HOW", "WHERE", "WHAT", "WHEN", "WHO", "GS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_conv_PS.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Conversation in PSQT sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 10
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.8,2.5,0.5,9.7,7.5,0,17.7,0,1.3,6.9]
width = 4 / 4 * np.random.rand(N)
colors = ['darkorange', 'pink', 'dodgerblue', 'magenta', 'darkturquoise', 'mediumorchid', 'lightsalmon', 'lawngreen', 'deepskyblue', 'red']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,11)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["U_EXPR", "T_W_REP", "N°_QUEST", "WHY", "HOW", "WHERE", "WHAT", "WHEN", "WHO", "GS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_conv_PSQT.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Conversation in EMSS sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 10
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.3,2.5,0.4,4.9,8.3,0.8,3.4,0.4,12.3,8.5]
width = 4 / 4 * np.random.rand(N)
colors = ['darkorange', 'pink', 'dodgerblue', 'magenta', 'darkturquoise', 'mediumorchid', 'lightsalmon', 'lawngreen', 'deepskyblue', 'red']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,11)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["U_EXPR", "T_W_REP", "N°_QUEST", "WHY", "HOW", "WHERE", "WHAT", "WHEN", "WHO", "GS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.10, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_conv_EMSS.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# THEMATIC RELATIONS

# %% [raw]
# Bar chart on polar axis for Thematic Relations in animal sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [7.6,2.9,2.6,0.7,1.1]
width = 4 / 4 * np.random.rand(N)
colors = ['crimson', 'yellowgreen', 'slateblue', 'cornflowerblue', 'tomato']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["SPATIAL", "TEMPORAL", "EVENT", "ASSOCIATIONS", "SPECIFICATION"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.15, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_ThRel_animal.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Thematic Relations in food sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.9,8.6,1.8,2.1,4.2]
width = 4 / 4 * np.random.rand(N)
colors = ['crimson', 'yellowgreen', 'slateblue', 'cornflowerblue', 'tomato']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["SPATIAL", "TEMPORAL", "EVENT", "ASSOCIATIONS", "SPECIFICATION"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.15, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_ThRel_food.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Thematic Relations in tool sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [7,5.9,3.5,0.8,2.4]
width = 4 / 4 * np.random.rand(N)
colors = ['crimson', 'yellowgreen', 'slateblue', 'cornflowerblue', 'tomato']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["SPATIAL", "TEMPORAL", "EVENT", "ASSOCIATIONS", "SPECIFICATION"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.15, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_ThRel_tool.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Thematic Relations in PS sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.2,3.4,0.3,1.4,2.3]
width = 4 / 4 * np.random.rand(N)
colors = ['crimson', 'yellowgreen', 'slateblue', 'cornflowerblue', 'tomato']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["SPATIAL", "TEMPORAL", "EVENT", "ASSOCIATIONS", "SPECIFICATION"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.15, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_ThRel_PS.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Thematic Relations in PSQT sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.6,4,0.6,2.2,2.7]
width = 4 / 4 * np.random.rand(N)
colors = ['crimson', 'yellowgreen', 'slateblue', 'cornflowerblue', 'tomato']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["SPATIAL", "TEMPORAL", "EVENT", "ASSOCIATIONS", "SPECIFICATION"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.15, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_ThRel_PSQT.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Thematic Relations in EMSS sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [1,2.1,1,1.4,0.1]
width = 4 / 4 * np.random.rand(N)
colors = ['crimson', 'yellowgreen', 'slateblue', 'cornflowerblue', 'tomato']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["SPATIAL", "TEMPORAL", "EVENT", "ASSOCIATIONS", "SPECIFICATION"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.15, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_ThRel_EMSS.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# INNER GROUNDING

# %% [raw]
# Bar chart on polar axis for Inner Grounding in animal sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.1,4,1,0,4.4]
width = 4 / 4 * np.random.rand(N)
colors = ['fuchsia', 'lime', 'yellow', 'blue', 'cyan']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["INTEROCEPTION", "EMOTION", "INTROSPECTION", "METACOGNITION", "BELIEF"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.2, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_InnGr_animal.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Inner Grounding in food sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [1.9,1.6,0.3,0.1,3.1]
width = 4 / 4 * np.random.rand(N)
colors = ['fuchsia', 'lime', 'yellow', 'blue', 'cyan']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["INTEROCEPTION", "EMOTION", "INTROSPECTION", "METACOGNITION", "BELIEF"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.2, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_InnGr_food.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Inner Grounding in tool sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.4,2.3,0.7,0,5.9]
width = 4 / 4 * np.random.rand(N)
colors = ['fuchsia', 'lime', 'yellow', 'blue', 'cyan']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["INTEROCEPTION", "EMOTION", "INTROSPECTION", "METACOGNITION", "BELIEF"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.2, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_InnGr_tool.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Inner Grounding in PS sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0,3.6,2,0.3,14.8]
width = 4 / 4 * np.random.rand(N)
colors = ['fuchsia', 'lime', 'yellow', 'blue', 'cyan']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["INTEROCEPTION", "EMOTION", "INTROSPECTION", "METACOGNITION", "BELIEF"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.2, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_InnGr_PS.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Inner Grounding in PSQT sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.1,3.8,1.1,1.5,10.8]
width = 4 / 4 * np.random.rand(N)
colors = ['fuchsia', 'lime', 'yellow', 'blue', 'cyan']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["INTEROCEPTION", "EMOTION", "INTROSPECTION", "METACOGNITION", "BELIEF"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.2, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_InnGr_PSQT.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [raw]
# Bar chart on polar axis for Inner Grounding in EMSS sentences

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 5
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.2,11.7,1.4,0.1,13.6]
width = 4 / 4 * np.random.rand(N)
colors = ['fuchsia', 'lime', 'yellow', 'blue', 'cyan']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,6)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["INTEROCEPTION", "EMOTION", "INTROSPECTION", "METACOGNITION", "BELIEF"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.2, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_InnGr_EMSS.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# TURN VARIABLE ALONE

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 6
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [58.4, 44.8, 41.5, 58.2, 51.8, 39]
width = 4 / 4 * np.random.rand(N)
colors = ['blue', 'orange', 'lightgreen', 'aqua', 'violet', 'gold']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,7)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["ANIMAL", "FOOD", "TOOL", "PS", "PSQT", "EMSS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.1, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_TURN.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ACTION ABSTRACT AND ACTION CONCRETE

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 6
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [0.5, 1, 1.2, 11.1, 6.6, 6.3]
width = 4 / 4 * np.random.rand(N)
colors = ['blue', 'orange', 'lightgreen', 'aqua', 'violet', 'gold']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,7)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["ANIMAL", "FOOD", "TOOL", "PS", "PSQT", "EMSS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.1, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_AA.jpg', bbox_inches='tight', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
# Compute pie slices
N = 6
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = [27.8,27.6,36.6, 3.3, 8.2, 2.3]
width = 4 / 4 * np.random.rand(N)
colors = ['blue', 'orange', 'lightgreen', 'aqua', 'violet', 'gold']

ax = plt.subplot(111, projection='polar')
# ax.set_rmax(2)
# ax.set_rticks([])
ticks= np.linspace(0,360,7)[:-1] 
ax.set_xticks(np.deg2rad(ticks))
ticklabels = ["ANIMAL", "FOOD", "TOOL", "PS", "PSQT", "EMSS"]
ax.set_xticklabels(ticklabels)

plt.gcf().canvas.draw()
angles = np.linspace(0,2*np.pi,len(ax.get_xticklabels())+1)
angles[np.cos(angles) < 0] = angles[np.cos(angles) < 0] + np.pi
angles = np.rad2deg(angles)
labels = []
for label, angle in zip(ax.get_xticklabels(), angles):
    x,y = label.get_position()
    lab = ax.text(x,y-.1, label.get_text(), transform=label.get_transform(),
                  ha=label.get_ha(), va=label.get_va())
    lab.set_rotation(angle)
    labels.append(lab)
ax.set_xticklabels([], fontsize = 30)

plt.subplots_adjust(top=1.5,bottom=0.32,left=0.05,right=0.95)
ax.bar(theta, radii, width=width, align = 'center', bottom=0.5, color=colors, alpha=0.5)

plt.savefig('BarChart on polar_AC.jpg', bbox_inches='tight', dpi=300)
plt.show()
